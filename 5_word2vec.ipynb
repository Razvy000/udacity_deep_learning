# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.17.1

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print(dictionary['the'])
print(reverse_dictionary[3])
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# 1
# and
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'anarchism', 'a', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.030140
# Nearest to war: detainees, dew, monarchist, charley, trent, compensation, soaring, orestes,
# Nearest to of: normale, blessings, posthumously, bellamy, tianjin, bishkek, fer, polity,
# Nearest to during: orientalis, bidder, kiang, herbal, presupposition, collegium, wehrmacht, scientist,
# Nearest to united: does, abernathy, vu, anterior, oxidised, hitler, eerie, haven,
# Nearest to than: boosts, mosaics, travel, moderator, fecture, amalgamation, inverses, nanda,
# Nearest to such: kipper, cease, finding, helpdesk, babysitter, deviations, autism, zionist,
# Nearest to these: julmust, ohm, urged, ji, childress, allah, welterweight, firmus,
# Nearest to many: fiscal, alder, shortages, aral, reggaeton, jolie, abductions, burning,
# Nearest to however: merian, businessmen, camped, deferred, polyn, chrono, antonin, detour,
# Nearest to called: interference, highly, keg, secretions, mariani, sweets, tempore, absent,
# Nearest to system: liquefaction, borgir, genius, charlatans, salamanca, apple, lambda, kemerovo,
# Nearest to th: manufacturers, sur, rossellini, fortunes, connotes, gene, stylistic, dione,
# Nearest to so: domain, retainers, prisma, paglia, isuzu, cubism, theorised, six,
# Nearest to two: exhibiting, zephaniah, gobind, conflict, peritoneum, risings, praise, shaker,
# Nearest to has: douard, rutland, heydrich, seth, lying, mathrm, lagged, oireachtas,
# Nearest to on: ericales, snow, untouched, birthdate, tapped, sargent, sm, conversational,
# Average loss at step 2000: 4.355091
# Average loss at step 4000: 3.869432
# Average loss at step 6000: 3.791527
# Average loss at step 8000: 3.686139
# Average loss at step 10000: 3.615662
# Nearest to war: detainees, soaring, dew, swore, blank, monarchist, tren, paula,
# Nearest to of: in, for, posthumously, and, schoolboy, at, normale, glamorgan,
# Nearest to during: orientalis, on, in, dauphin, brendan, collegium, panhandle, watchtower,
# Nearest to united: anterior, dreamcast, heuss, rest, highest, lammas, honeybee, wikibook,
# Nearest to than: mosaics, boosts, triumphal, embody, inverses, altaic, betrays, countered,
# Nearest to such: deviations, finding, well, cease, accompaniment, esq, kipper, dehydration,
# Nearest to these: many, bally, sorcerers, light, ayla, julmust, cryopreserved, booking,
# Nearest to many: some, tapped, these, protists, jolie, reggaeton, blacks, robotic,
# Nearest to however: but, native, merian, keywork, before, polyn, castiglione, ambassador,
# Nearest to called: interference, highly, permitting, leonidas, accompanied, secretions, marquee, unknowns,
# Nearest to system: liquefaction, caucasus, charlatans, lanterns, apple, borgir, piaget, lengthen,
# Nearest to th: manufacturers, three, quake, generalised, gene, zero, speaks, hanja,
# Nearest to so: domain, paglia, equinox, moshoeshoe, cubism, sized, can, ecd,
# Nearest to two: three, five, four, six, eight, seven, nine, one,
# Nearest to has: had, is, have, was, immanuel, muluzi, inhalants, foreman,
# Nearest to on: in, during, by, publicity, jimmie, at, joke, birthdate,
# Average loss at step 12000: 3.604423
# Average loss at step 14000: 3.571896
# Average loss at step 16000: 3.408366
# Average loss at step 18000: 3.457212
# Average loss at step 20000: 3.542549
# Nearest to war: tren, dew, kaunas, blank, welles, paula, cristobal, regulators,
# Nearest to of: fiddlers, posthumously, mamertines, for, in, plosives, pastimes, whose,
# Nearest to during: orientalis, on, in, dauphin, when, under, watchtower, at,
# Nearest to united: highest, rest, dreamcast, anterior, violated, heuss, revisionist, lanzarote,
# Nearest to than: boosts, or, mosaics, embody, moderator, triumphal, medical, betrays,
# Nearest to such: well, finding, deviations, dehydration, these, classified, accompaniment, regarded,
# Nearest to these: many, some, several, all, other, they, their, such,
# Nearest to many: some, these, several, tapped, other, most, all, their,
# Nearest to however: but, that, before, merian, lynched, deferred, although, ambassador,
# Nearest to called: interference, highly, marquee, unknowns, gloom, see, stylistic, volution,
# Nearest to system: liquefaction, lanterns, apple, caucasus, piaget, amhara, slicing, charlatans,
# Nearest to th: bc, manufacturers, cdm, hanja, quake, generalised, bourne, gene,
# Nearest to so: paglia, domain, equinox, thereof, dances, sized, athletes, rub,
# Nearest to two: three, five, four, six, seven, one, eight, nine,
# Nearest to has: had, have, was, is, muluzi, pinnacle, worked, having,
# Nearest to on: in, during, through, legionary, birthdate, sm, at, into,
# Average loss at step 22000: 3.501929
# Average loss at step 24000: 3.488189
# Average loss at step 26000: 3.474755
# Average loss at step 28000: 3.480726
# Average loss at step 30000: 3.502088
# Nearest to war: dew, nis, darboux, dutchman, discontinuity, hermas, bravo, dorms,
# Nearest to of: in, relaunch, mamertines, for, from, spills, including, trilogy,
# Nearest to during: orientalis, on, after, under, dauphin, in, when, at,
# Nearest to united: highest, rest, lanzarote, violated, dreamcast, fourth, anterior, harpoon,
# Nearest to than: or, mosaics, boosts, duce, moderator, bomb, embody, way,
# Nearest to such: well, these, other, finding, regarded, seen, known, sravaka,
# Nearest to these: some, many, all, they, such, several, their, other,
# Nearest to many: some, several, these, all, most, other, tapped, those,
# Nearest to however: but, although, that, while, spitfire, mumps, though, forcing,
# Nearest to called: marquee, unguarded, highly, quite, mithra, gloom, considered, unknowns,
# Nearest to system: liquefaction, slicing, apple, louvain, amhara, clarke, myocardial, piaget,
# Nearest to th: bc, six, three, cdm, generalised, manufacturers, praetor, five,
# Nearest to so: paglia, equinox, less, sized, frequently, domain, thereof, fadh,
# Nearest to two: four, three, one, six, five, seven, eight, zero,
# Nearest to has: had, have, is, was, having, inhalants, online, immanuel,
# Nearest to on: upon, during, in, through, sm, legionary, at, keynesianism,
# Average loss at step 32000: 3.504399
# Average loss at step 34000: 3.490458
# Average loss at step 36000: 3.451063
# Average loss at step 38000: 3.297856
# Average loss at step 40000: 3.435417
# Nearest to war: dew, dutchman, soter, nis, regulators, darboux, dorms, soaring,
# Nearest to of: in, from, plosives, surveys, symmetrically, lame, for, terrains,
# Nearest to during: on, under, at, after, orientalis, in, against, collegium,
# Nearest to united: rest, highest, violated, lanzarote, harpoon, anterior, fourth, virility,
# Nearest to than: or, mosaics, connie, much, way, plebeian, no, hot,
# Nearest to such: these, well, known, regarded, finding, relief, sravaka, codec,
# Nearest to these: some, many, such, several, they, those, various, different,
# Nearest to many: some, several, these, those, various, all, most, both,
# Nearest to however: but, although, that, and, while, though, it, which,
# Nearest to called: quite, tendons, gloom, marquee, see, unguarded, vassals, considered,
# Nearest to system: systems, liquefaction, amhara, apple, principled, identify, lanterns, ibos,
# Nearest to th: bc, cdm, praetor, ad, manufacturers, quake, st, hanja,
# Nearest to so: equinox, paglia, less, frequently, rub, newspeak, scaffolding, disgruntled,
# Nearest to two: three, six, five, four, seven, one, eight, nine,
# Nearest to has: had, have, was, is, having, corsican, heels, pinnacle,
# Nearest to on: during, upon, at, from, unary, in, mainline, within,
# Average loss at step 42000: 3.432414
# Average loss at step 44000: 3.450354
# Average loss at step 46000: 3.448840
# Average loss at step 48000: 3.353120
# Average loss at step 50000: 3.387008
# Nearest to war: dew, dutchman, nis, entrepreneur, soter, walkie, darboux, soaring,
# Nearest to of: in, including, and, plosives, spills, disenchantment, astrological, progressive,
# Nearest to during: after, at, under, in, when, vdp, through, against,
# Nearest to united: violated, rest, highest, lanzarote, fourth, harpoon, abernathy, virility,
# Nearest to than: or, much, plebeian, mosaics, triumphal, hot, unpowered, relational,
# Nearest to such: well, these, regarded, known, finding, sravaka, relief, specific,
# Nearest to these: some, many, such, several, they, various, both, those,
# Nearest to many: some, several, these, various, both, those, most, tapped,
# Nearest to however: but, although, while, though, that, where, when, until,
# Nearest to called: known, marquee, vassals, named, tendons, see, vapour, unguarded,
# Nearest to system: systems, liquefaction, principled, amhara, psychology, ibos, diligent, identify,
# Nearest to th: bc, praetor, szil, st, five, three, hanja, ad,
# Nearest to so: equinox, ayling, domain, frequently, cabot, newspeak, scaffolding, snapped,
# Nearest to two: three, six, four, seven, one, five, eight, zero,
# Nearest to has: had, have, was, is, inhalants, having, hinged, heels,
# Nearest to on: upon, in, at, sm, into, through, within, heretics,
# Average loss at step 52000: 3.431086
# Average loss at step 54000: 3.424410
# Average loss at step 56000: 3.438604
# Average loss at step 58000: 3.396930
# Average loss at step 60000: 3.391461
# Nearest to war: nis, dutchman, soter, entrepreneur, northernmost, dew, onyx, encroachment,
# Nearest to of: for, plosives, in, same, timer, mamertines, and, surveys,
# Nearest to during: after, in, under, before, although, throughout, at, vdp,
# Nearest to united: violated, virility, rest, harpoon, highest, following, lanzarote, roman,
# Nearest to than: much, or, and, but, plebeian, slightly, radium, connie,
# Nearest to such: well, regarded, these, known, including, many, relief, follows,
# Nearest to these: many, some, several, those, all, such, they, which,
# Nearest to many: some, several, these, various, all, most, those, tapped,
# Nearest to however: but, although, though, that, while, which, where, since,
# Nearest to called: used, considered, named, unelected, simile, unguarded, quite, known,
# Nearest to system: systems, liquefaction, principled, apple, amhara, psychology, software, louvain,
# Nearest to th: bc, seven, eight, praetor, five, szil, ad, st,
# Nearest to so: equinox, domain, too, ayling, less, paglia, frequently, rub,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to has: had, have, is, was, inhalants, corsican, constituci, having,
# Nearest to on: upon, through, in, within, sm, suri, joke, legionary,
# Average loss at step 62000: 3.234945
# Average loss at step 64000: 3.255026
# Average loss at step 66000: 3.397884
# Average loss at step 68000: 3.391911
# Average loss at step 70000: 3.358677
# Nearest to war: northernmost, dutchman, nis, soter, cia, newfoundland, entrepreneur, encroachment,
# Nearest to of: including, plosives, lexikon, include, lame, in, and, original,
# Nearest to during: after, in, before, under, throughout, although, at, among,
# Nearest to united: violated, virility, rest, harpoon, roman, dreamcast, highest, anterior,
# Nearest to than: or, but, lambert, and, much, unfaithful, no, plebeian,
# Nearest to such: these, well, known, including, regarded, like, sravaka, codec,
# Nearest to these: such, many, some, those, several, various, are, their,
# Nearest to many: some, several, various, these, all, most, both, those,
# Nearest to however: but, although, though, that, while, where, which, since,
# Nearest to called: named, used, considered, whispered, unguarded, grue, tendons, gloom,
# Nearest to system: systems, liquefaction, program, millimetres, playa, broadway, cleanly, louvain,
# Nearest to th: bc, szil, fifth, praetor, st, doyle, ad, seven,
# Nearest to so: equinox, too, thus, less, thereof, sometimes, domain, snapped,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to has: had, have, is, was, muluzi, having, reis, although,
# Nearest to on: upon, through, in, within, sm, heretics, about, during,
# Average loss at step 72000: 3.368693
# Average loss at step 74000: 3.345792
# Average loss at step 76000: 3.315814
# Average loss at step 78000: 3.346698
# Average loss at step 80000: 3.378859
# Nearest to war: northernmost, nis, dutchman, entrepreneur, guardianship, newfoundland, swelling, walkie,
# Nearest to of: including, in, rovers, elaborately, czechoslovak, lame, csc, disenchantment,
# Nearest to during: after, in, throughout, when, despite, until, before, under,
# Nearest to united: roman, virility, violated, harpoon, dreamcast, rest, hampered, lanzarote,
# Nearest to than: or, but, much, while, betrays, lambert, ethelbert, relational,
# Nearest to such: well, these, regarded, follows, known, including, classified, sravaka,
# Nearest to these: several, many, those, various, some, such, multiple, they,
# Nearest to many: some, several, various, these, both, most, those, all,
# Nearest to however: although, but, that, though, while, alle, where, which,
# Nearest to called: used, named, considered, known, referred, unguarded, tendons, whispered,
# Nearest to system: systems, program, liquefaction, myocardial, psychology, apple, software, hermeticism,
# Nearest to th: bc, fifth, five, szil, twentieth, three, eight, seven,
# Nearest to so: equinox, less, before, paglia, gellius, too, rub, lying,
# Nearest to two: three, four, six, seven, five, one, eight, zero,
# Nearest to has: had, is, have, was, muluzi, although, inhalants, having,
# Nearest to on: upon, in, through, during, sm, at, within, legionary,
# Average loss at step 82000: 3.404567
# Average loss at step 84000: 3.411713
# Average loss at step 86000: 3.389095
# Average loss at step 88000: 3.348263
# Average loss at step 90000: 3.366760
# Nearest to war: northernmost, nis, dutchman, uu, swelling, soter, cia, newfoundland,
# Nearest to of: including, for, during, in, includes, and, dyskinesia, throughout,
# Nearest to during: in, after, until, throughout, despite, under, since, when,
# Nearest to united: harpoon, rest, roman, violated, virility, hampered, highest, dreamcast,
# Nearest to than: much, betrays, or, lambert, relational, least, no, while,
# Nearest to such: well, known, these, regarded, follows, seen, loyola, classified,
# Nearest to these: several, many, some, those, such, various, are, multiple,
# Nearest to many: some, several, various, these, most, all, both, those,
# Nearest to however: but, although, that, though, while, since, alle, nevertheless,
# Nearest to called: used, named, considered, referred, known, synchronize, tha, see,
# Nearest to system: systems, program, liquefaction, purpose, playa, hermeneutics, mcg, hermeticism,
# Nearest to th: bc, fifth, szil, st, seven, eight, twentieth, one,
# Nearest to so: thus, equinox, too, gellius, matrilineal, paglia, lying, then,
# Nearest to two: three, four, five, six, eight, seven, one, nine,
# Nearest to has: had, have, is, was, having, inhalants, since, corsican,
# Nearest to on: upon, through, sm, legionary, under, in, laurens, against,
# Average loss at step 92000: 3.398788
# Average loss at step 94000: 3.251400
# Average loss at step 96000: 3.359932
# Average loss at step 98000: 3.239669
# Average loss at step 100000: 3.355313
# Nearest to war: swelling, nis, northernmost, battle, encroachment, cia, walkie, soter,
# Nearest to of: including, in, and, commended, lexikon, original, bowser, logged,
# Nearest to during: in, throughout, after, despite, until, when, since, before,
# Nearest to united: harpoon, rest, roman, violated, hampered, following, virility, urges,
# Nearest to than: or, lambert, much, betrays, overarching, touchdowns, least, unfaithful,
# Nearest to such: known, well, regarded, these, follows, seen, many, including,
# Nearest to these: several, many, some, those, various, multiple, all, certain,
# Nearest to many: some, several, various, these, all, numerous, those, few,
# Nearest to however: but, although, that, though, while, and, which, where,
# Nearest to called: named, used, referred, known, unguarded, tendons, unitas, goyen,
# Nearest to system: systems, program, hermeticism, gush, liquefaction, software, louvain, playa,
# Nearest to th: fifth, bc, szil, twentieth, nd, st, rd, narnia,
# Nearest to so: thus, equinox, too, paglia, sometimes, when, thereof, less,
# Nearest to two: four, three, five, six, seven, eight, one, nine,
# Nearest to has: had, have, is, was, having, inhalants, since, annibale,
# Nearest to on: upon, in, at, through, near, within, legionary, under,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
